# %%
import duckdb
import pandas as pd 
import os

con = duckdb.connect("qttr.db")

pd.set_option('display.max_columns', None)

#einranken = con.execute('SELECT * FROM "Einranken" ').fetchdf()
einranken = pd.read_csv(os.path.join('data', 'Einranken'))
einranken
# Out:
#        InterneNr  Nachname    Vorname GeschlechtImSpielbetrieb Geburtsdatum  \
# 0      NU2498935       Sun       Yang                        M   2008-02-28
# 1      NU2379770      Wang    Chen Ce                        M   2003-04-14
# 2      NU2617607      Zhai      Jiale                        M   2008-10-24
# 3      NU2379684       Kuo  Guan-Hong                        M   2008-10-24
# 4      NU2425927       Yan     Yutong                        W   2008-01-18
# ...          ...       ...        ...                      ...          ...
# 52593  NU2261885     Zhang  Katherina                        W   2013-04-26
# 52594  NU2227997     Ziehn    Tristan                        M   2009-02-01
# 52595  NU2228122    Zörner  Christian                        M   2008-05-03
# 52596  NU2237990     Zuber   Mariella                        W   2010-04-28
# 52597  NU2191613  Zukancic       Anel                        M   2009-09-12
#
#       Einstufungsdatum zuletzt   TTR  Anzahl Einzel gesamt  \
# 0                   2023-03-27  2605                   126
# 1                   2022-06-07  2542                    32
# 2                   2023-08-28  2538                    44
# 3                   2022-05-24  2527                   199
# 4                   2022-09-10  2519                    96
# ...                        ...   ...                   ...
# 52593               2021-10-24   633                    17
# 52594               2020-09-19   691                    10
# 52595               2020-09-26   821                    25
# 52596               2021-10-03   819                    25
# 52597               2020-10-10   838                    12
#
#       Einstufungsart zuletzt Nation Altersklasse            Spielklasse  \
# 0                          T    CHN          nan                    nan
# 1                          T    CHN          nan                    nan
# 2                          T    CHN          nan                    nan
# 3                          T    TPE          nan                    nan
# 4                          T    CHN          nan                    nan
# ...                      ...    ...          ...                    ...
# 52593                      T    GER          nan                    nan
# 52594                      P    GER          nan                    nan
# 52595                      P    GER    Jungen 19  Kreisliga D Nachwuchs
# 52596                      P    GER          nan                    nan
# 52597                      P    GER          nan                    nan
#
#        Einstufungswert zuletzt  TTR_Q1  Einzel_Q1  TTR_Q2  Einzel_Q2  TTR_Q3  \
# 0                         2402  2327.0       63.0  2338.0       78.0  2383.0
# 1                         2638  2527.0       17.0  2509.0       20.0  2454.0
# 2                         2318  2342.0       40.0  2348.0       44.0  2498.0
# 3                         2175  2157.0       47.0  2173.0       47.0  2189.0
# 4                         2552  2418.0       23.0  2281.0       74.0  2297.0
# ...                        ...     ...        ...     ...        ...     ...
# 52593                      650   616.0       11.0   615.0       17.0   621.0
# 52594                      795   709.0        5.0   715.0        5.0   721.0
# 52595                      810   738.0        7.0   744.0        7.0   750.0
# 52596                      776   748.0       13.0   832.0       22.0   838.0
# 52597                      858   822.0        8.0   828.0        8.0   834.0
#
#        Einzel_Q3  TTR_Q4  Einzel_Q4  TTR_Q0  Einzel_Q0
# 0           98.0  2437.0      125.0  2312.0       63.0
# 1           29.0  2463.0       32.0  2527.0       17.0
# 2           44.0  2518.0       44.0  2326.0       40.0
# 3           47.0  2247.0       70.0  2084.0       14.0
# 4           74.0  2306.0       88.0  2449.0       14.0
# ...          ...     ...        ...     ...        ...
# 52593       17.0   627.0       17.0   610.0       11.0
# 52594        5.0   667.0       10.0   703.0        5.0
# 52595        7.0   740.0       11.0   732.0        7.0
# 52596       22.0   795.0       25.0   742.0       13.0
# 52597        8.0   836.0       10.0   816.0        8.0
#
# [52598 rows x 23 columns]

# %%
statisch = einranken[einranken["Einstufungsart zuletzt"] == "S"] #leer, veraltet - erste initalisierungen
tunier = einranken[einranken["Einstufungsart zuletzt"] == "T"]
meldepos = einranken[einranken["Einstufungsart zuletzt"] == "P"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setze ein ansprechendes Style-Theme
sns.set_theme(style="whitegrid")

# Erstelle Histogramm + Dichtekurve
plt.figure(figsize=(10, 6))
sns.histplot(einranken["TTR"], kde=True, bins=30, color='skyblue')
sns.histplot(einranken["Einstufungswert zuletzt"], kde=True, bins=30, color='red')

plt.title("Spieler:innen Verteilung")
plt.xlabel("TTR")
plt.ylabel("Häufigkeit")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

y2011 = con.execute("SELECT TTR FROM 'q-ttr-liste_20120211_komplett'").fetchdf()
y2018 = con.execute("SELECT TTR FROM 'q-ttr-liste_20180811_komplett'").fetchdf()
y2025 = con.execute("SELECT TTR FROM 'q-ttr-liste_20250211_komplett'").fetchdf()

# Setze ein ansprechendes Style-Theme
sns.set_theme(style="whitegrid")

# Erstelle Histogramm + Dichtekurve
plt.figure(figsize=(10, 6))
sns.histplot(y2011, x="TTR", kde=True, bins=30, stat="probability", color='red', label='2012', alpha=0.5)
sns.histplot(y2018, x="TTR", kde=True, bins=30, stat="probability", color='orange', label='2018', alpha=0.5)
sns.histplot(y2025, x="TTR", kde=True, bins=30, stat="probability", color='skyblue', label='2025', alpha=0.5)



plt.title("Punkte Deflation?")
plt.xlabel("TTR")
plt.ylabel("Häufigkeit")
plt.show()

# %%
compare = {"2011" : y2011, "2018": y2018, "2025": y2025} 

for i in compare:
    print(f"{i}: \n Min: {compare[i]['TTR'].min()} \n Median: {int(compare[i]['TTR'].median())} \n Max: {compare[i]['TTR'].max()} \n \n")
# Out:
# 2011:
#  Min: 277
#  Median: 1149
#  Max: 2598
#
#
# 2018:
#  Min: 508
#  Median: 1095
#  Max: 2816
#
#
# 2025:
#  Min: 473
#  Median: 1058
#  Max: 2834

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Style
sns.set_theme(style="whitegrid")

# Relevante Spalten
spalten = [
    "Einstufungswert zuletzt",
    "TTR_Q0", "TTR_Q1", "TTR_Q2", "TTR_Q3", "TTR_Q4", "TTR"
]

# Farben fix pro Spalte
farben = sns.color_palette("husl", n_colors=len(spalten))
farben_dict = {spalte: farbe for spalte, farbe in zip(spalten, farben)}

# Alle Paarungen vorbereiten
paare = [(spalten[i], spalten[i + 1]) for i in range(len(spalten) - 1)]


n_cols = 3
n_rows = -(-len(paare) // n_cols)  # Decken auf ganze Zahl auf

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 4 * n_rows), sharey=True)

# Falls axes 1D ist → flatten
axes = axes.flatten()

# Schleife über alle Paarungen
for idx, (spalte1, spalte2) in enumerate(paare):
    ax = axes[idx]
    
    sns.histplot(einranken[spalte1], kde=True, bins=30, stat="probability",
                 color=farben_dict[spalte1], label=spalte1, alpha=0.6, ax=ax)
    
    sns.histplot(einranken[spalte2], kde=True, bins=30, stat="probability",
                 color=farben_dict[spalte2], label=spalte2, alpha=0.6, ax=ax)
    
    ax.set_title(f"{spalte1} vs. {spalte2}")
    ax.set_xlabel("TTR")
    ax.set_ylabel("Rel. Häufigkeit")
    ax.legend()

# Leere Achsen (falls z. B. nur 5 Paare, aber 8 Plätze)
for j in range(len(paare), len(axes)):
    fig.delaxes(axes[j])

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

art = {"Meldeposition" : meldepos,"Tunier" : tunier}

# Setze ein ansprechendes Style-Theme
sns.set_theme(style="whitegrid")
for i in art:
    # Erstelle Histogramm + Dichtekurve
    plt.figure(figsize=(10, 6))
    sns.histplot(art[i]["Einstufungswert zuletzt"], kde=True, bins=30, color='gray')
    sns.histplot(art[i]["TTR_Q4"], kde=True, bins=30, color='red')
    plt.title(f"Einranksystem {i}")
    plt.xlabel("TTR")
    plt.ylabel("Häufigkeit")
    plt.show()

# %%
einranken.columns
# Out:
# Index(['InterneNr', 'Nachname', 'Vorname', 'GeschlechtImSpielbetrieb',
#        'Geburtsdatum', 'Einstufungsdatum zuletzt', 'TTR',
#        'Anzahl Einzel gesamt', 'Einstufungsart zuletzt', 'Nation',
#        'Altersklasse', 'Spielklasse', 'Einstufungswert zuletzt', 'TTR_Q1',
#        'Einzel_Q1', 'TTR_Q2', 'Einzel_Q2', 'TTR_Q3', 'Einzel_Q3', 'TTR_Q4',
#        'Einzel_Q4', 'TTR_Q0', 'Einzel_Q0'],
#       dtype='object')

# %%
if True:    
    import pandas as pd
    import seaborn as sns
    import matplotlib.pyplot as plt
    import statsmodels.formula.api as smf
    from scipy.stats import ttest_ind

    # Schritt 1: Fehler berechnen
    einranken["TTR_Fehler"] = einranken["TTR_Q4"] - einranken["Einstufungswert zuletzt"]

    # Schritt 2: Verteilung des Fehlers
    plt.figure(figsize=(8, 5))
    sns.histplot(einranken["TTR_Fehler"], bins=40, kde=True, color="steelblue", stat="probability")
    plt.title("Verteilung des TTR-Fehlers (TTR_Q4 - Einstufung)")
    plt.xlabel("Fehlerwert")
    plt.ylabel("Relative Häufigkeit")
    plt.axvline(0, color='red', linestyle='--', label="Keine Abweichung")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Schritt 3: Boxplots nach Gruppen
    gruppenvariablen = [
        'GeschlechtImSpielbetrieb',
        'Altersklasse',
        'Spielklasse',
        'Einstufungsart zuletzt'
    ]

    for var in gruppenvariablen:
        plt.figure(figsize=(10, 5))
        sns.boxplot(x=var, y="TTR_Fehler", data=einranken)
        plt.title(f"TTR-Fehler nach {var}")
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

    # Schritt 4: Lineares Regressionsmodell (Dummy-Kodierung automatisch)
    modell = smf.ols(
        "TTR_Fehler ~ C(GeschlechtImSpielbetrieb) + C(Altersklasse) + C(Spielklasse) + C(Q('Einstufungsart zuletzt'))",
        data=einranken
    ).fit()

    print(modell.summary())

    # Schritt 5: t-Test (Beispiel: Geschlecht m vs w)
    gruppe_m = einranken[einranken["GeschlechtImSpielbetrieb"] == "m"]["TTR_Fehler"]
    gruppe_w = einranken[einranken["GeschlechtImSpielbetrieb"] == "w"]["TTR_Fehler"]

    t_test_ergebnis = ttest_ind(gruppe_m.dropna(), gruppe_w.dropna(), equal_var=False)
    print("\nT-Test Ergebnis (m vs. w):", t_test_ergebnis)

    # Optional: Streudiagramm mit Regression
    sns.lmplot(x="Einstufungswert zuletzt", y="TTR_Q4", hue="GeschlechtImSpielbetrieb", data=einranken,
            height=6, aspect=1.2, scatter_kws={"alpha": 0.4})
    plt.title("Einstufungswert vs. TTR_Q4 mit Regressionslinie")
    plt.tight_layout()
    plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             TTR_Fehler   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                  0.122
# Method:                 Least Squares   F-statistic:                     18.91
# Date:                Fri, 16 May 2025   Prob (F-statistic):               0.00
# Time:                        21:49:58   Log-Likelihood:            -2.4140e+05
# No. Observations:               40299   AIC:                         4.834e+05
# Df Residuals:                   39986   BIC:                         4.861e+05
# Df Model:                         312
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                       -159.4138     47.980     -3.322      0.001    -253.456     -65.371
# C(GeschlechtImSpielbetrieb)[T.W]                                 -26.3564      1.492    -17.662      0.000     -29.281     -23.431
# C(Altersklasse)[T.Damen/Herren]                                 1.123e+12   1.72e+12      0.654      0.513   -2.25e+12    4.49e+12
# C(Altersklasse)[T.Freizeit/Betriebssport]                        1.62e+12   2.48e+12      0.654      0.513   -3.24e+12    6.48e+12
# C(Altersklasse)[T.Herren]                                         94.5949      5.819     16.256      0.000      83.189     106.000
# C(Altersklasse)[T.Jugend 13]                                   -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Jugend 19]                                   -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Jungen]                                      -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Jungen 11]                                   -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Jungen 12]                                   -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Jungen 13]                                   -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Jungen 14]                                   -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Jungen 15]                                   -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Jungen 15/19]                                -9.537e+10   1.46e+11     -0.654      0.513   -3.81e+11    1.91e+11
# C(Altersklasse)[T.Jungen 19]                                   -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Mädchen 11]                                  -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Mädchen 12]                                  -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Mädchen 13]                                  -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Mädchen 15]                                  -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Mädchen 19]                                  -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Mädchen 19/Jungen 19]                        -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Schüler]                                     -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Schüler 15]                                  -1.182e+13   1.81e+13     -0.654      0.513   -4.73e+13    2.36e+13
# C(Altersklasse)[T.Senioren]                                     7.349e+09   1.12e+10      0.654      0.513   -1.47e+10    2.94e+10
# C(Altersklasse)[T.Senioren 40]                                  7.349e+09   1.12e+10      0.654      0.513   -1.47e+10    2.94e+10
# C(Altersklasse)[T.Senioren 50]                                  7.349e+09   1.12e+10      0.654      0.513   -1.47e+10    2.94e+10
# C(Altersklasse)[T.Senioren 60]                                  7.349e+09   1.12e+10      0.654      0.513   -1.47e+10    2.94e+10
# C(Altersklasse)[T.Senioren 70]                                  7.349e+09   1.12e+10      0.654      0.513   -1.47e+10    2.94e+10
# C(Altersklasse)[T.Seniorinnen 40]                               7.349e+09   1.12e+10      0.654      0.513   -1.47e+10    2.94e+10
# C(Spielklasse)[T.1. Bezirksklasse]                                20.9760     14.153      1.482      0.138      -6.764      48.716
# C(Spielklasse)[T.1. Bezirksklasse D/H]                            53.2150     17.777      2.993      0.003      18.372      88.058
# C(Spielklasse)[T.1. Bezirksklasse Jugend]                       1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.1. Bezirksklasse Senioren]                    -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.1. Bezirksliga]                                  82.9090     15.387      5.388      0.000      52.749     113.069
# C(Spielklasse)[T.1. Bezirksliga D/H]                             103.9187     23.960      4.337      0.000      56.957     150.881
# C(Spielklasse)[T.1. Bezirksliga J/S]                            1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.1. Bezirksliga Jugend]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.1. Freizeit/Betriebssport-Klasse]              -1.62e+12   2.48e+12     -0.654      0.513   -6.48e+12    3.24e+12
# C(Spielklasse)[T.1. Kreisklasse]                                  14.7743     14.188      1.041      0.298     -13.035      42.584
# C(Spielklasse)[T.1. Kreisklasse D/H]                               6.4753     12.899      0.502      0.616     -18.808      31.758
# C(Spielklasse)[T.1. Kreisklasse Damen/Herren]                    -29.9266     22.520     -1.329      0.184     -74.067      14.214
# C(Spielklasse)[T.1. Kreisklasse Herren]                          -24.6460     17.375     -1.418      0.156     -58.701       9.409
# C(Spielklasse)[T.1. Kreisklasse Jugend 13]                      1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.1. Kreisklasse Jugend 19]                      1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.1. Kreisklasse NW]                             1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.1. Kreisklasse Senioren]                      -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.1. Kreisliga D/H]                                25.7082     15.524      1.656      0.098      -4.720      56.136
# C(Spielklasse)[T.1. Kreisliga Damen/Herren]                       69.0114     49.997      1.380      0.167     -28.984     167.006
# C(Spielklasse)[T.1. Kreisliga Herren]                            -38.3240     38.606     -0.993      0.321    -113.992      37.344
# C(Spielklasse)[T.1. Landesklasse D/H]                             77.1234     27.800      2.774      0.006      22.635     131.612
# C(Spielklasse)[T.1. Landesliga D/H]                               77.7124     41.451      1.875      0.061      -3.533     158.958
# C(Spielklasse)[T.1. Pfalzliga D/H]                                79.1848     41.508      1.908      0.056      -2.172     160.541
# C(Spielklasse)[T.1. Regionalklasse J/S]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.1. Stadtklasse D/H]                               4.6839     27.799      0.168      0.866     -49.803      59.171
# C(Spielklasse)[T.1. Stadtklasse H]                               -49.1611     49.995     -0.983      0.325    -147.152      48.830
# C(Spielklasse)[T.1. Stadtklasse Herren]                          135.1444     97.792      1.382      0.167     -56.529     326.818
# C(Spielklasse)[T.1. Stadtliga]                                 -1.123e+12   1.72e+12     -0.654      0.513   -4.49e+12    2.25e+12
# C(Spielklasse)[T.2. Bezirksklasse]                               -21.6538     12.565     -1.723      0.085     -46.281       2.974
# C(Spielklasse)[T.2. Bezirksklasse D/H]                            67.1767     21.183      3.171      0.002      25.658     108.696
# C(Spielklasse)[T.2. Bezirksliga]                                  47.8166     15.019      3.184      0.001      18.380      77.254
# C(Spielklasse)[T.2. Bezirksliga D/H]                              67.9453     21.582      3.148      0.002      25.644     110.247
# C(Spielklasse)[T.2. Bezirksliga J/S]                            1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.2. Bezirksliga Jugend]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.2. Bezirksliga Senioren]                      -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.2. Bundesliga]                                   83.2643     55.160      1.510      0.131     -24.850     191.379
# C(Spielklasse)[T.2. Freizeit/Betriebssport-Klasse]              -1.62e+12   2.48e+12     -0.654      0.513   -6.48e+12    3.24e+12
# C(Spielklasse)[T.2. Kreisklasse]                                 -38.7675     12.772     -3.035      0.002     -63.801     -13.734
# C(Spielklasse)[T.2. Kreisklasse D/H]                             -23.3425     12.548     -1.860      0.063     -47.937       1.251
# C(Spielklasse)[T.2. Kreisklasse Damen/Herren]                    -74.6792     21.421     -3.486      0.000    -116.665     -32.694
# C(Spielklasse)[T.2. Kreisklasse Herren]                          -72.6866     14.383     -5.054      0.000    -100.878     -44.495
# C(Spielklasse)[T.2. Kreisklasse Jugend 19]                      1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.2. Kreisklasse NW]                             1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.2. Kreisklasse Senioren]                      -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.2. Kreisliga D/H]                                -9.7804     14.130     -0.692      0.489     -37.476      17.916
# C(Spielklasse)[T.2. Kreisliga Damen/Herren]                       97.2967     32.967      2.951      0.003      32.681     161.912
# C(Spielklasse)[T.2. Landesklasse D/H]                             39.4172     17.611      2.238      0.025       4.900      73.934
# C(Spielklasse)[T.2. Landesliga D/H]                               85.4578     30.622      2.791      0.005      25.437     145.478
# C(Spielklasse)[T.2. Pfalzliga D/H]                                26.9182     41.505      0.649      0.517     -54.432     108.268
# C(Spielklasse)[T.2. Regionalklasse J/S]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.2. Stadtklasse D/H]                             -34.4065     20.958     -1.642      0.101     -75.484       6.671
# C(Spielklasse)[T.2. Stadtklasse H]                                74.9933     41.408      1.811      0.070      -6.168     156.155
# C(Spielklasse)[T.2. Stadtklasse Herren]                           74.6079     45.040      1.656      0.098     -13.672     162.888
# C(Spielklasse)[T.3. Bezirksklasse]                               -43.1658     12.250     -3.524      0.000     -67.177     -19.155
# C(Spielklasse)[T.3. Bezirksliga D/H]                              12.3699     31.641      0.391      0.696     -49.648      74.388
# C(Spielklasse)[T.3. Bundesliga]                                 -131.2017     50.091     -2.619      0.009    -229.381     -33.022
# C(Spielklasse)[T.3. Freizeit/Betriebssport-Klasse]              -1.62e+12   2.48e+12     -0.654      0.513   -6.48e+12    3.24e+12
# C(Spielklasse)[T.3. Kreisklasse]                                 -77.7891     12.444     -6.251      0.000    -102.179     -53.399
# C(Spielklasse)[T.3. Kreisklasse (3er)]                           -92.0027     14.518     -6.337      0.000    -120.459     -63.547
# C(Spielklasse)[T.3. Kreisklasse (4)]                            -107.0762     17.612     -6.080      0.000    -141.596     -72.556
# C(Spielklasse)[T.3. Kreisklasse D/H]                             -44.5873     12.424     -3.589      0.000     -68.939     -20.235
# C(Spielklasse)[T.3. Kreisklasse Damen/Herren]                    -60.1692     20.542     -2.929      0.003    -100.433     -19.906
# C(Spielklasse)[T.3. Kreisklasse Jugend 19]                      1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.3. Kreisklasse NW]                             1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.3. Kreisliga D/H]                               -34.6515     13.832     -2.505      0.012     -61.762      -7.541
# C(Spielklasse)[T.3. Kreisliga Damen/Herren]                       77.9288     34.517      2.258      0.024      10.275     145.582
# C(Spielklasse)[T.3. Landesklasse D/H]                             46.2585     21.421      2.160      0.031       4.273      88.244
# C(Spielklasse)[T.3. Liga]                                      -1.123e+12   1.72e+12     -0.654      0.513   -4.49e+12    2.25e+12
# C(Spielklasse)[T.3. Regionalklasse J/S]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.3. Stadtklasse D/H]                             -75.9498     30.494     -2.491      0.013    -135.718     -16.181
# C(Spielklasse)[T.3. Stadtklasse H]                               -47.4689     34.518     -1.375      0.169    -115.124      20.187
# C(Spielklasse)[T.3. Stadtklasse Herren]                          -44.9427     24.361     -1.845      0.065     -92.690       2.805
# C(Spielklasse)[T.4. Bezirksklasse]                               -59.3333     12.379     -4.793      0.000     -83.596     -35.070
# C(Spielklasse)[T.4. Freizeit/Betriebssport-Klasse]              -1.62e+12   2.48e+12     -0.654      0.513   -6.48e+12    3.24e+12
# C(Spielklasse)[T.4. Kreisklasse]                                 -55.8638     14.412     -3.876      0.000     -84.112     -27.616
# C(Spielklasse)[T.4. Kreisklasse D/H]                             -57.1111     12.555     -4.549      0.000     -81.720     -32.503
# C(Spielklasse)[T.4. Kreisklasse NW]                             1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.4. Kreisklasse Staffel A D/H]                   -11.3359     25.849     -0.439      0.661     -62.000      39.328
# C(Spielklasse)[T.4. Kreisklasse Staffel B D/H]                   -47.2327     20.540     -2.299      0.021     -87.493      -6.973
# C(Spielklasse)[T.4. Kreisliga D/H]                               -49.2967     13.287     -3.710      0.000     -75.340     -23.254
# C(Spielklasse)[T.4. Landesklasse D/H]                            -59.3070     23.939     -2.477      0.013    -106.228     -12.386
# C(Spielklasse)[T.4. Regionalklasse J/S]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.4. Stadtklasse H]                               -32.4620     22.839     -1.421      0.155     -77.228      12.304
# C(Spielklasse)[T.4er-Mannschaften]                               -72.4427     15.403     -4.703      0.000    -102.632     -42.253
# C(Spielklasse)[T.4er-Senioren]                                 -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.5. Kreisklasse D/H]                             -58.2951     13.225     -4.408      0.000     -84.217     -32.373
# C(Spielklasse)[T.5. Kreisklasse NW]                             1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.5. Kreisliga D/H]                               -85.2577     17.612     -4.841      0.000    -119.778     -50.737
# C(Spielklasse)[T.5. Reginalklasse J/S]                          1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.5.Stadtklasse H]                               -105.9082     23.545     -4.498      0.000    -152.058     -59.759
# C(Spielklasse)[T.6. Kreisklasse D/H]                             -53.9479     15.014     -3.593      0.000     -83.375     -24.521
# C(Spielklasse)[T.6. Kreisklasse NW]                             1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.6. Regionalklasse J/S]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.7. Kreisklasse D/H]                             -43.9885     17.612     -2.498      0.013     -78.509      -9.468
# C(Spielklasse)[T.8. Kreisklasse D/H]                            -111.2219     22.222     -5.005      0.000    -154.777     -67.667
# C(Spielklasse)[T.Bambini Bezirksliga]                           1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirks-Mannschaftsmeisterschaften Nachwuchs]  1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksklasse]                                   68.2858     17.282      3.951      0.000      34.412     102.160
# C(Spielklasse)[T.Bezirksklasse  D/H]                             -28.9947     49.996     -0.580      0.562    -126.988      68.998
# C(Spielklasse)[T.Bezirksklasse A]                                 69.8508     14.967      4.667      0.000      40.514      99.187
# C(Spielklasse)[T.Bezirksklasse A Erwachsene]                     149.6202     45.055      3.321      0.001      61.311     237.929
# C(Spielklasse)[T.Bezirksklasse A Nachwuchs]                     1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksklasse B]                                 39.9402     13.727      2.910      0.004      13.034      66.846
# C(Spielklasse)[T.Bezirksklasse B Erwachsene]                     127.4560     36.424      3.499      0.000      56.065     198.847
# C(Spielklasse)[T.Bezirksklasse B Nachwuchs]                     1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksklasse B Senioren]                     -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.Bezirksklasse C]                                 -4.3035     12.677     -0.339      0.734     -29.151      20.544
# C(Spielklasse)[T.Bezirksklasse C Nachwuchs]                     1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksklasse D]                                -48.4413     12.302     -3.938      0.000     -72.553     -24.330
# C(Spielklasse)[T.Bezirksklasse D Nachwuchs]                     1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksklasse D/H]                                5.2028     19.987      0.260      0.795     -33.972      44.377
# C(Spielklasse)[T.Bezirksklasse E]                                -67.1981     12.804     -5.248      0.000     -92.295     -42.102
# C(Spielklasse)[T.Bezirksklasse Erwachsene]                        58.3023     19.084      3.055      0.002      20.897      95.708
# C(Spielklasse)[T.Bezirksklasse Herren]                           103.4491     24.816      4.169      0.000      54.810     152.088
# C(Spielklasse)[T.Bezirksklasse J/S]                             1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksklasse Jugend]                          1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksklasse NW]                              1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksklasse Nachwuchs]                       1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksklasse Senioren]                       -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.Bezirksliga]                                     98.9266     16.917      5.848      0.000      65.769     132.084
# C(Spielklasse)[T.Bezirksliga Bambini]                           1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksliga D/H]                                125.8762     19.677      6.397      0.000      87.309     164.444
# C(Spielklasse)[T.Bezirksliga Erwachsene]                          65.2421     21.103      3.092      0.002      23.880     106.604
# C(Spielklasse)[T.Bezirksliga Herren]                             133.9728     41.418      3.235      0.001      52.793     215.153
# C(Spielklasse)[T.Bezirksliga J]                                 1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksliga J/S]                               1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksliga Jugend]                            1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksliga Jugend 19]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksliga NW]                                1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksliga Nachwuchs]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksliga Sen]                              -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.Bezirksoberliga]                                 73.0575     15.920      4.589      0.000      41.853     104.262
# C(Spielklasse)[T.Bezirksoberliga D/H]                             88.6671     29.490      3.007      0.003      30.866     146.468
# C(Spielklasse)[T.Bezirksoberliga Jugend]                        1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksoberliga Nachwuchs]                     1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Bezirksoberliga Senioren]                     -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.Bremen-Liga Damen/Herren]                       -12.8768     57.309     -0.225      0.822    -125.204      99.451
# C(Spielklasse)[T.Bremen-Liga Jugend]                            1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Freizeit/Betriebssport-Liga]                   -1.62e+12   2.48e+12     -0.654      0.513   -6.48e+12    3.24e+12
# C(Spielklasse)[T.Hamburg Liga D/H]                               327.6578     50.016      6.551      0.000     229.625     425.690
# C(Spielklasse)[T.Hessenliga]                                     -44.2652     38.610     -1.146      0.252    -119.942      31.412
# C(Spielklasse)[T.Jugend 1. Kreisklasse]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend 1.Kreisklasse]                          1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend 15]                                     1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend 19]                                     1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend 2. Kreisklasse]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend 3. Kreisklasse]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend Bezirksklasse]                          1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend Bezirksliga]                            1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend Bezirksoberliga]                        1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend Hessenliga]                             1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend Kreisklasse]                            1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend Kreisliga]                              1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend Sonderklasse]                           1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Jugend Verbandsliga]                           1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisklasse A]                                   25.0692     16.498      1.520      0.129      -7.267      57.406
# C(Spielklasse)[T.Kreisklasse A D/H]                              -31.2504     13.936     -2.242      0.025     -58.566      -3.935
# C(Spielklasse)[T.Kreisklasse A Erwachsene]                       -50.3267     12.762     -3.944      0.000     -75.340     -25.313
# C(Spielklasse)[T.Kreisklasse A Jugend]                          1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisklasse A Nachwuchs]                       1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisklasse B]                                  -20.2121     15.690     -1.288      0.198     -50.965      10.541
# C(Spielklasse)[T.Kreisklasse B D/H]                              -61.9575     13.985     -4.430      0.000     -89.368     -34.547
# C(Spielklasse)[T.Kreisklasse B Erwachsene]                       -59.0346     15.872     -3.719      0.000     -90.145     -27.924
# C(Spielklasse)[T.Kreisklasse B Jugend]                          1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisklasse B4]                                 -96.8384     69.671     -1.390      0.165    -233.395      39.719
# C(Spielklasse)[T.Kreisklasse C]                                  -45.6229     13.975     -3.265      0.001     -73.013     -18.232
# C(Spielklasse)[T.Kreisklasse C Erwachsene]                       -24.9342     19.077     -1.307      0.191     -62.326      12.457
# C(Spielklasse)[T.Kreisklasse C4]                                 -56.3167     29.487     -1.910      0.056    -114.112       1.479
# C(Spielklasse)[T.Kreisklasse D]                                  -70.6165     13.667     -5.167      0.000     -97.404     -43.829
# C(Spielklasse)[T.Kreisklasse D Erwachsene]                       -38.0997     19.986     -1.906      0.057     -77.274       1.074
# C(Spielklasse)[T.Kreisklasse D/H]                                -56.3535     14.782     -3.812      0.000     -85.326     -27.381
# C(Spielklasse)[T.Kreisklasse E Erwachsene]                       -74.0260     18.699     -3.959      0.000    -110.677     -37.375
# C(Spielklasse)[T.Kreisklasse Herren]                             -73.4534     16.347     -4.493      0.000    -105.494     -41.413
# C(Spielklasse)[T.Kreisklasse J 15]                              1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisklasse J/S]                               1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisklasse Jugend]                            1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisklasse Jugend 15]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisklasse Jugend 19]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisklasse Jungen 15]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisklasse NW]                                1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisklasse Nord D/H]                           -76.8425     32.966     -2.331      0.020    -141.457     -12.228
# C(Spielklasse)[T.Kreisklasse S]                                 1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisklasse Süd D/H]                            -47.9605     27.799     -1.725      0.084    -102.447       6.526
# C(Spielklasse)[T.Kreisklasse/ Herren]                            -68.1684     25.850     -2.637      0.008    -118.834     -17.503
# C(Spielklasse)[T.Kreisliga]                                       73.1948     15.317      4.779      0.000      43.174     103.216
# C(Spielklasse)[T.Kreisliga A]                                    -58.8483     69.671     -0.845      0.398    -195.405      77.709
# C(Spielklasse)[T.Kreisliga A Erwachsene]                          21.1425     14.488      1.459      0.144      -7.255      49.540
# C(Spielklasse)[T.Kreisliga A Nachwuchs]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga A Senioren]                         -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.Kreisliga B]                                     -8.9690     97.811     -0.092      0.927    -200.681     182.743
# C(Spielklasse)[T.Kreisliga B Erwachsene]                         -30.9271     13.007     -2.378      0.017     -56.421      -5.433
# C(Spielklasse)[T.Kreisliga B Nachwuchs]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga C Erwachsene]                         -57.0999     13.029     -4.382      0.000     -82.638     -31.562
# C(Spielklasse)[T.Kreisliga C Nachwuchs]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga D Erwachsene]                         -60.4735     14.343     -4.216      0.000     -88.585     -32.362
# C(Spielklasse)[T.Kreisliga D Nachwuchs]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga D/H]                                   -2.4876     12.971     -0.192      0.848     -27.911      22.936
# C(Spielklasse)[T.Kreisliga E Erwachsene]                          65.3374     27.799      2.350      0.019      10.850     119.825
# C(Spielklasse)[T.Kreisliga E Nachwuchse]                        1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga F Erwachsene]                         -32.0062     36.362     -0.880      0.379    -103.277      39.264
# C(Spielklasse)[T.Kreisliga G Erwachsene]                         -29.9717     25.849     -1.160      0.246     -80.636      20.693
# C(Spielklasse)[T.Kreisliga H Erwachsene]                        -104.2195     24.360     -4.278      0.000    -151.965     -56.474
# C(Spielklasse)[T.Kreisliga Herren]                                 9.6202     15.209      0.633      0.527     -20.190      39.430
# C(Spielklasse)[T.Kreisliga J]                                   1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga J 15]                                1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga J 19]                                1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga J/S]                                 1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga Jugend]                              1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga Jugend 13]                           1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga Jugend 15]                           1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga Jugend 19]                           1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga Jungen]                              1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga Jungen 15]                           1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga Jungen 19]                           1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga Mansfeld D/H]                          26.8389     31.640      0.848      0.396     -35.177      88.855
# C(Spielklasse)[T.Kreisliga NW]                                  1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga Nord D/H]                             -70.9031     69.671     -1.018      0.309    -207.460      65.654
# C(Spielklasse)[T.Kreisliga S]                                   1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga Sch]                                 1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga Schüler 15]                          1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga Süd D/H]                             -108.4897     97.802     -1.109      0.267    -300.184      83.205
# C(Spielklasse)[T.Kreisliga Süd J]                               1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisliga/ Herren]                                7.0391     34.516      0.204      0.838     -60.614      74.692
# C(Spielklasse)[T.Kreisoberliga]                                   89.1108     30.493      2.922      0.003      29.345     148.877
# C(Spielklasse)[T.Kreisoberliga D/H]                               46.8648     20.541      2.282      0.023       6.605      87.125
# C(Spielklasse)[T.Kreisoberliga J]                               1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisoberliga Jungen 15]                       1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisoberliga Jungen 19]                       1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisoberliga Mädchen 15]                      1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Kreisoberliga/ Herren]                          -12.3807     32.966     -0.376      0.707     -76.995      52.233
# C(Spielklasse)[T.Landesklasse Erwachsene]                         14.9090     28.666      0.520      0.603     -41.277      71.095
# C(Spielklasse)[T.Landesliga]                                      70.5398     24.387      2.893      0.004      22.741     118.338
# C(Spielklasse)[T.Landesliga D/H]                                 156.7688     27.087      5.788      0.000     103.677     209.861
# C(Spielklasse)[T.Landesliga Erwachsene]                          211.9280     57.341      3.696      0.000      99.538     324.318
# C(Spielklasse)[T.Landesliga Herren]                               22.4563     97.924      0.229      0.819    -169.477     214.389
# C(Spielklasse)[T.Landesliga J/S]                                1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Landesliga Jungen]                             1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Landesliga Nachwuchs]                          1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Landesliga Sen]                               -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.Leistungsklasse J/S]                           1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.NRW-Liga]                                        43.9813     57.586      0.764      0.445     -68.889     156.852
# C(Spielklasse)[T.NRW-Liga Jugend]                               1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Nachwuchsliga]                                 1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Nachwuchsliga Staffel A]                       1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Niedersachsenliga NW]                          1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Oberliga]                                        50.6144     25.435      1.990      0.047       0.762     100.467
# C(Spielklasse)[T.Pfalzliga J/S]                                 1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Regionalliga]                                    53.7677     31.971      1.682      0.093      -8.896     116.431
# C(Spielklasse)[T.Saarlandliga]                                    53.8097     69.899      0.770      0.441     -83.194     190.814
# C(Spielklasse)[T.Saarlandliga J/S]                              1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Saarlandliga Sen]                             -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.Sachsenliga D/H]                                182.2482     41.508      4.391      0.000     100.892     263.605
# C(Spielklasse)[T.Schnupperrunde]                                1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Senioren Ü40]                                 -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.Senioren Ü50]                                 -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.Senioren/Seniorinnen]                         -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.Seniorinnen Ü40]                              -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.Stadtklasse J]                                 1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Stadtliga 1 Damen/Herren]                        65.0087     45.040      1.443      0.149     -23.271     153.289
# C(Spielklasse)[T.Stadtliga 2 Damen/Herren]                       100.6820     38.606      2.608      0.009      25.014     176.350
# C(Spielklasse)[T.Stadtliga D/H]                                  -22.1626     21.938     -1.010      0.312     -65.161      20.836
# C(Spielklasse)[T.Stadtliga H]                                     75.4770     57.309      1.317      0.188     -36.850     187.804
# C(Spielklasse)[T.Stadtliga Herren]                               115.1125     49.996      2.302      0.021      17.119     213.106
# C(Spielklasse)[T.Stadtliga J]                                   1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Stadtliga J 19]                                1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Stadtliga J/S]                                 1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Stadtliga Jugend]                              1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Stadtoberliga D/H]                              103.9307     45.040      2.308      0.021      15.652     192.210
# C(Spielklasse)[T.Starter-Liga]                                  -104.7046     17.025     -6.150      0.000    -138.074     -71.335
# C(Spielklasse)[T.Thüringenliga]                                  165.0261     51.396      3.211      0.001      64.289     265.763
# C(Spielklasse)[T.Thüringenliga Mädchen 19]                      1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Verbandsklasse]                                 -14.8051     57.340     -0.258      0.796    -127.193      97.583
# C(Spielklasse)[T.Verbandsklasse Jugend]                         1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Verbandsliga]                                    69.2449     22.626      3.060      0.002      24.898     113.592
# C(Spielklasse)[T.Verbandsliga D/H]                                62.4076     20.762      3.006      0.003      21.714     103.101
# C(Spielklasse)[T.Verbandsliga Erwachsene]                       -128.1276     69.687     -1.839      0.066    -264.716       8.461
# C(Spielklasse)[T.Verbandsliga Herren]                            251.0969     97.792      2.568      0.010      59.423     442.771
# C(Spielklasse)[T.Verbandsliga J]                                9.537e+10   1.46e+11      0.654      0.513   -1.91e+11    3.81e+11
# C(Spielklasse)[T.Verbandsliga J/S]                              1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Verbandsliga Jugend]                           1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Verbandsliga Jugend 19]                        1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Verbandsliga Nachwuchs]                        1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Verbandsliga Sen]                             -7.349e+09   1.12e+10     -0.654      0.513   -2.94e+10    1.47e+10
# C(Spielklasse)[T.Verbandsoberliga]                               114.5731     36.480      3.141      0.002      43.071     186.075
# C(Spielklasse)[T.Verbandsoberliga Erwachsene]                     22.7396     38.670      0.588      0.557     -53.054      98.533
# C(Spielklasse)[T.Verbandsoberliga Jugend]                       1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Spielklasse)[T.Verbandsoberliga Jugend 19]                    1.182e+13   1.81e+13      0.654      0.513   -2.36e+13    4.73e+13
# C(Q('Einstufungsart zuletzt'))[T.P]                              110.6673     45.845      2.414      0.016      20.811     200.524
# C(Q('Einstufungsart zuletzt'))[T.T]                              150.7661     45.872      3.287      0.001      60.856     240.676
# ==============================================================================
# Omnibus:                     2467.619   Durbin-Watson:                   1.577
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3917.893
# Skew:                           0.504   Prob(JB):                         0.00
# Kurtosis:                       4.147   Cond. No.                     1.23e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.98e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# T-Test Ergebnis (m vs. w): TtestResult(statistic=np.float64(nan), pvalue=np.float64(nan), df=np.float64(nan))
# C:\Users\nicla\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\_lib\deprecation.py:234: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return f(*args, **kwargs)

# %%
if True:
    # Ergebnisse aus Tabelle 1 (Koeffizienten-Tabelle)
    regression_alot = modell.summary2().tables[1].copy()

    '''
    # Optional: Signifikanzsterne hinzufügen
    def significance_stars(p):
        if p < 0.001:
            return '***'
        elif p < 0.01:
            return '**'
        elif p < 0.05:
            return '*'
        else:
            return ''

    results_df["Signifikanz"] = results_df["P>|t|"].apply(significance_stars)
    '''

    # Jetzt hast du ein sauberes DataFrame mit allen Resultaten
regression_alot.sort_values("P>|t|")
# Out:
#                                                  Coef.   Std.Err.          t  \
# C(GeschlechtImSpielbetrieb)[T.W]            -26.356350   1.492281 -17.661790
# C(Altersklasse)[T.Herren]                    94.594878   5.819089  16.255959
# C(Spielklasse)[T.Hamburg Liga D/H]          327.657826  50.016043   6.551054
# C(Spielklasse)[T.Bezirksliga D/H]           125.876210  19.677030   6.397114
# C(Spielklasse)[T.3. Kreisklasse (3er)]      -92.002719  14.518198  -6.337062
# ...                                                ...        ...        ...
# C(Spielklasse)[T.Bremen-Liga Damen/Herren]  -12.876776  57.309229  -0.224689
# C(Spielklasse)[T.Kreisliga/ Herren]           7.039081  34.516431   0.203934
# C(Spielklasse)[T.Kreisliga D/H]              -2.487616  12.970955  -0.191784
# C(Spielklasse)[T.1. Stadtklasse D/H]          4.683881  27.799050   0.168491
# C(Spielklasse)[T.Kreisliga B]                -8.968958  97.811306  -0.091697
#
#                                                    P>|t|      [0.025  \
# C(GeschlechtImSpielbetrieb)[T.W]            1.518440e-69  -29.281256
# C(Altersklasse)[T.Herren]                   3.140545e-59   83.189327
# C(Spielklasse)[T.Hamburg Liga D/H]          5.782413e-11  229.625215
# C(Spielklasse)[T.Bezirksliga D/H]           1.600874e-10   87.308772
# C(Spielklasse)[T.3. Kreisklasse (3er)]      2.366773e-10 -120.458726
# ...                                                  ...         ...
# C(Spielklasse)[T.Bremen-Liga Damen/Herren]  8.222221e-01 -125.204200
# C(Spielklasse)[T.Kreisliga/ Herren]         8.384060e-01  -60.613928
# C(Spielklasse)[T.Kreisliga D/H]             8.479127e-01  -27.910990
# C(Spielklasse)[T.1. Stadtklasse D/H]        8.661981e-01  -49.802905
# C(Spielklasse)[T.Kreisliga B]               9.269396e-01 -200.681398
#
#                                                 0.975]
# C(GeschlechtImSpielbetrieb)[T.W]            -23.431445
# C(Altersklasse)[T.Herren]                   106.000429
# C(Spielklasse)[T.Hamburg Liga D/H]          425.690438
# C(Spielklasse)[T.Bezirksliga D/H]           164.443648
# C(Spielklasse)[T.3. Kreisklasse (3er)]      -63.546712
# ...                                                ...
# C(Spielklasse)[T.Bremen-Liga Damen/Herren]   99.450649
# C(Spielklasse)[T.Kreisliga/ Herren]          74.692089
# C(Spielklasse)[T.Kreisliga D/H]              22.935759
# C(Spielklasse)[T.1. Stadtklasse D/H]         59.170666
# C(Spielklasse)[T.Kreisliga B]               182.743481
#
# [318 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Dictionaries mit DataFrames und Bezeichnungen
art = {"Meldeposition": meldepos, "Tunier": tunier}
geschlechter = {"W": "Weiblich", "M": "Männlich"}

# Setze einheitliches Seaborn-Theme
sns.set_theme(style="whitegrid")

# 2x2 Subplots mit gemeinsamem X- und Y-Skalierung
fig, axs = plt.subplots(2, 2, figsize=(14, 10), sharex=True, sharey=True)

# Bestimme globalen X-Achsenbereich (über beide Systeme und Geschlechter hinweg)
all_values = []
for df in art.values():
    for geschl_code in geschlechter:
        df_filt = df[df["GeschlechtImSpielbetrieb"] == geschl_code]
        all_values.extend(df_filt["Einstufungswert zuletzt"].dropna())
        all_values.extend(df_filt["TTR_Q2"].dropna())

xmin = min(all_values)
xmax = max(all_values)

# Schleife über Systeme und Geschlechter
for col_idx, (art_name, df) in enumerate(art.items()):
    for row_idx, (geschl_code, geschl_name) in enumerate(geschlechter.items()):
        ax = axs[row_idx, col_idx]
        df_filtered = df[df["GeschlechtImSpielbetrieb"] == geschl_code]

        sns.histplot(df_filtered["Einstufungswert zuletzt"], kde=True, bins=30, 
                     stat="probability", color='gray', ax=ax, label="Einstufung")
        sns.histplot(df_filtered["TTR_Q2"], kde=True, bins=30, 
                     stat="probability", color='red', ax=ax, label="TTR_Q2")

        ax.set_xlim(xmin, xmax)  # X-Achse fixieren
        ax.set_title(f"{art_name} – {geschl_name}")
        ax.set_xlabel("TTR")
        ax.set_ylabel("Relative Häufigkeit")
        ax.legend()

# Layout anpassen
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

weiblich = einranken[einranken["GeschlechtImSpielbetrieb"] == "W"]
maennlich = einranken[einranken["GeschlechtImSpielbetrieb"] == "M"]

fehler_W = weiblich["TTR_Q2"] - weiblich["Einstufungswert zuletzt"]
fehler_M = maennlich["TTR_Q2"] - maennlich["Einstufungswert zuletzt"]

ges = {"weiblich": fehler_W, "männlich": fehler_M}

for i in ges:
    # Neue Figur und Achse erstellen
    fig, ax = plt.subplots(figsize=(8, 5))

    # Histogramm
    sns.histplot(ges[i], kde=True, bins=30, stat="probability", color='red', ax=ax, label=f"Fehler der {i} Spieler:innen")

    # Median-Linie
    ax.axvline(ges[i].median(), color="black", linestyle="--", linewidth=2, label="Median")

    # Achsenbeschriftung etc.
    ax.set_ylabel("Relative Häufigkeit")
    ax.set_xlabel(f"Fehler Punkte")
    ax.set_title(f"Verteilung der Fehler – {i.capitalize()}")
    ax.legend()

    plt.tight_layout()
    plt.show()
    print(f" Median hier: {ges[i].median()}")
    print(f" Mittelwert hier: {ges[i].mean()}")
# Out:
#  Median hier: -44.0
#  Mittelwert hier: -41.465418043824215
#  Median hier: -20.0
#  Mittelwert hier: -14.650633595174323
